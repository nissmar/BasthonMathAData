# %%
from validation_prof import *

# %% [markdown]
# ### Question 1

# %% [markdown]
# Écris la fonction identité:

# %%
def f(x):
    return

# %%
### VALIDATION ###
validation_question_1(f)

# %% [markdown]
# ### Question 2

# %% [markdown]
# Écris la fonction carrée:

# %%
def g(x):
    return

# %%
### VALIDATION ###
validation_question_2(g)

# %% [markdown]
# ### Question 3

# %% [markdown]
# Écris la fonction valeur absolue

# %%
### Écris la fonction carré 

def h(x):
    return

# %%
validation_question_3(h)
